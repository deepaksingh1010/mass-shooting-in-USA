# %%
# Import the MySQL connector library to interact with the MySQL database
import mysql.connector

# Function to create a new database
def create_database():
    try:
        # Establish a connection to the MySQL server without specifying a database
        conn = mysql.connector.connect(
            host="localhost",
            user="root",
            password="1234567890"
        )
        cursor = conn.cursor()
        # Drop the database if it already exists to start fresh
        cursor.execute("DROP DATABASE IF EXISTS crime_data_db")
        # Create a new database named 'crime_data_db'
        cursor.execute("CREATE DATABASE crime_data_db")
        print("Database created successfully........")
    except mysql.connector.Error as err:
        # Print any errors that occur during the process
        print(f"Error: {err}")
    finally:
        # Ensure the connection is closed properly
        if conn.is_connected():
            cursor.close()
            conn.close()

# Function to create a table within the database
def create_table():
    try:
        # Establish a connection to the MySQL server and specify the database to use
        conn = mysql.connector.connect(
            host="localhost",
            database="crime_data_db",
            user="root",
            password="1234567890"
        )
        cursor = conn.cursor()
        # Execute the SQL command to create a table named 'crime_data'
        cursor.execute('''
            CREATE TABLE crime_data (
                incident_date DATE,          -- Column for the date of the incident
                state VARCHAR(100),          -- Column for the state where the incident occurred
                city VARCHAR(100),           -- Column for the city where the incident occurred
                address VARCHAR(255),        -- Column for the address of the incident
                victims_killed INT,          -- Column for the number of victims killed
                victims_injured INT,         -- Column for the number of victims injured
                suspects_killed INT,         -- Column for the number of suspects killed
                suspects_injured INT,        -- Column for the number of suspects injured
                suspects_arrested INT        -- Column for the number of suspects arrested
            )
        ''')
        # Commit the changes to the database
        conn.commit()
        print("Table created successfully........")
    except mysql.connector.Error as err:
        # Print any errors that occur during the process
        print(f"Error: {err}")
    finally:
        # Ensure the connection is closed properly
        if conn.is_connected():
            cursor.close()
            conn.close()

# Call the functions to create the database and the table
create_database()
create_table()
# Out:
# Database created successfully........
# Table created successfully........

# %%
# Import necessary libraries
from selenium import webdriver
from bs4 import BeautifulSoup
from datetime import datetime
import mysql.connector
import time

# Function to create and return a connection to the MySQL database
def get_db_connection():
    conn = mysql.connector.connect(
        host="localhost",  # Database host
        database="crime_data_db",  # Database name
        user="root",  # Database user
        password="1234567890"  # Database password
    )
    return conn

# Function to configure and return a Selenium WebDriver for Chrome
def get_driver():
    options = webdriver.ChromeOptions()
    options.add_argument('--headless')  # Run Chrome in headless mode
    driver = webdriver.Chrome(options=options)
    return driver

# Function to navigate to a URL using Selenium and return the page's BeautifulSoup object
def scrape_data(driver, base_url):
    driver.get(base_url)
    time.sleep(5)  # Wait for the dynamic content to load
    soup = BeautifulSoup(driver.page_source, 'html.parser')
    return soup

# Function to parse data from a BeautifulSoup object and insert it into the MySQL database
def parse_and_insert_data(soup, conn):
    cursor = conn.cursor()  # Create a cursor object using the connection
    data = []  # Initialize a list to store the data records
    table = soup.find('table', class_='sticky-enabled')  # Find the table with class 'sticky-enabled'
    if table:
        rows = table.find('tbody').find_all('tr')  # Find all rows in the table body
        for row in rows:
            cols = row.find_all('td')  # Find all columns in the row
            if cols:
                try:
                    # Convert the incident date from string to a datetime object and then format it for MySQL
                    date_str = cols[1].text.strip()
                    formatted_date = datetime.strptime(date_str, '%B %d, %Y').strftime('%Y-%m-%d')
                    # Prepare the record for insertion
                    record = (
                        formatted_date,
                        cols[2].text.strip(),  # State
                        cols[3].text.strip(),  # City or County
                        cols[4].text.strip(),  # Address
                        int(cols[5].text.strip()),  # Victims Killed
                        int(cols[6].text.strip()),  # Victims Injured
                        int(cols[7].text.strip()),  # Suspects Killed
                        int(cols[8].text.strip()),  # Suspects Injured
                        int(cols[9].text.strip()),  # Suspects Arrested
                    )
                    data.append(record)  # Add the record to the data list
                    # SQL query to insert the record into the database
                    query = '''INSERT INTO crime_data
                               (incident_date, state, city, address, victims_killed, victims_injured, suspects_killed, suspects_injured, suspects_arrested)
                               VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s)'''
                    cursor.execute(query, record)  # Execute the query with the record data
                    conn.commit()  # Commit the transaction
                    print("Inserted data:", record)  # Print the inserted data for verification
                except Exception as e:
                    print(f"Error inserting data: {e}")  # Print any error during insertion
    else:
        print("Table not found.")  # Print a message if the table isn't found
    cursor.close()  # Close the cursor

# Main function to orchestrate the scraping and insertion process
def main():
    driver = get_driver()  # Get a Selenium WebDriver
    conn = get_db_connection()  # Get a database connection
    for year in range(2014, 2024):  # Iterate through the years of interest
        page = 0  # Initialize page counter
        has_next_page = True  # Flag to control pagination
        while has_next_page:  # While there are more pages to scrape
            # Construct the URL based on the year and page
            if year <= 2015:
                url = f"https://www.gunviolencearchive.org/reports/mass-shootings/{year}?page={page}"
            else:
                url = f"https://www.gunviolencearchive.org/reports/mass-shooting?year={year}&page={page}"
            print(f"Scraping data for {year}, page {page}")  # Print the current scraping action
            soup = scrape_data(driver, url)  # Scrape the page
            parse_and_insert_data(soup, conn)  # Parse the scraped data and insert it into the database
            next_page_link = soup.find('a', title="Go to next page")  # Find the link to the next page
            has_next_page = bool(next_page_link)  # Update the flag based on the presence of the next page link
            page += 1  # Increment the page counter
    driver.quit()  # Quit the WebDriver
    conn.close()  # Close the database connection
    print("Data scraping and insertion completed.")  # Print completion message

if __name__ == "__main__":
    main()  # Execute the main function
# Out:
# Scraping data for 2014, page 0
# Inserted data: ('2014-12-29', 'Louisiana', 'New Orleans', 'Poydras and Bolivar', 0, 4, 0, 0, 0)
# Inserted data: ('2014-12-27', 'California', 'Los Angeles', '8800 block of South Figueroa Street', 1, 3, 0, 0, 0)
# Inserted data: ('2014-12-27', 'California', 'Sacramento', '4000 block of May Street', 0, 4, 0, 0, 0)
# Inserted data: ('2014-12-26', 'Illinois', 'East St. Louis', '2500 block of Summit Avenue', 1, 3, 0, 0, 0)
# Inserted data: ('2014-12-24', 'Missouri', 'Saint Louis', '18th and Pine', 1, 3, 0, 0, 0)
# Inserted data: ('2014-12-23', 'Kentucky', 'Winchester', '260 Oxford Dr', 1, 3, 0, 0, 2)
# Inserted data: ('2014-12-22', 'Michigan', 'Detroit', 'Charlevoix and Philip', 1, 3, 0, 0, 0)
# Inserted data: ('2014-12-22', 'New York', 'Webster', '191 Lake Rd', 3, 2, 1, 0, 0)
# Inserted data: ('2014-12-22', 'Illinois', 'Chicago', '5700 block of South Green Street', 0, 5, 0, 0, 0)
# Inserted data: ('2014-12-21', 'Florida', 'Sarasota', '4034 N Washington Blvd', 2, 2, 0, 0, 0)
# Inserted data: ('2014-12-21', 'Mississippi', 'Waynesboro', 'Central Avenue', 1, 4, 0, 0, 2)
# Inserted data: ('2014-12-21', 'Illinois', 'Calumet City', '600 block of Escanba', 1, 8, 0, 0, 0)
# Inserted data: ('2014-12-20', 'Illinois', 'Rockford', '3200 block of Montrose Avenue', 4, 0, 0, 0, 1)
# Inserted data: ('2014-12-16', 'New Jersey', 'Elizabeth', 'Anna Street', 0, 4, 0, 0, 0)
# Inserted data: ('2014-12-15', 'Pennsylvania', 'Lansdale', '100 block of West 5th St', 6, 0, 1, 0, 0)
# Inserted data: ('2014-12-14', 'Florida', 'Miami', '1311 Northwest 2nd Avenue', 1, 4, 0, 0, 0)
# Inserted data: ('2014-12-13', 'Florida', 'Tampa', '810 E. Skagway Ave.', 0, 5, 0, 0, 0)
# Inserted data: ('2014-12-12', 'Oregon', 'Portland', '717 North Killingsworth Court', 0, 4, 0, 0, 3)
# Inserted data: ('2014-12-07', 'Indiana', 'South Bend', '16000 block of Roosevelt Road', 0, 4, 0, 0, 0)
# Inserted data: ('2014-12-02', 'Missouri', 'Saint Louis', '6000 block of Virginia Avenue', 1, 3, 0, 2, 0)
# Inserted data: ('2014-12-02', 'Virginia', 'Newport News', '6128 Jefferson Ave', 0, 5, 0, 0, 0)
# Inserted data: ('2014-11-30', 'Tennessee', 'Chattanooga', '2412 East 13th Street', 0, 5, 0, 0, 0)
# Inserted data: ('2014-11-30', 'New York', 'Brooklyn', '375 Remsen Avenue', 0, 4, 0, 0, 0)
# Inserted data: ('2014-11-29', 'Georgia', 'Atlanta', '1600 block of Richmond Avenue', 3, 2, 0, 0, 0)
# Inserted data: ('2014-11-29', 'New Jersey', 'Newark', '348 S Orange Ave', 1, 3, 0, 0, 0)
# Scraping data for 2014, page 1
# Inserted data: ('2014-11-28', 'Tennessee', 'Memphis', '1849 East Brooks Road', 0, 4, 0, 0, 0)
# Inserted data: ('2014-11-27', 'Texas', 'Georgetown', 'Pvt Rd 934', 2, 3, 0, 0, 0)
# Inserted data: ('2014-11-26', 'California', 'San Francisco', 'Mission and 13th streets', 0, 6, 0, 0, 0)
# Inserted data: ('2014-11-23', 'Virginia', 'Parksley', 'Parksley Road', 0, 4, 0, 0, 0)
# Inserted data: ('2014-11-23', 'Colorado', 'Denver', 'Federal Boulevard and 16th Avenue', 1, 4, 0, 0, 0)
# Inserted data: ('2014-11-22', 'Ohio', 'Cleveland', '1443 E 92nd St', 4, 1, 0, 0, 1)
# Inserted data: ('2014-11-22', 'South Dakota', 'Sisseton', 'Fourth Avenue', 3, 1, 1, 0, 0)
# Inserted data: ('2014-11-22', 'Ohio', 'Springfield', 'Clifton Avenue and Rice Street', 1, 3, 0, 0, 0)
# Inserted data: ('2014-11-21', 'Pennsylvania', 'Pittsburgh', '600 block of Miller Avenue', 0, 6, 0, 0, 0)
# Inserted data: ('2014-11-19', 'Illinois', 'Chicago', '700 block of North St. Louis Avenue', 1, 3, 0, 0, 0)
# Inserted data: ('2014-11-18', 'Nevada', 'North Las Vegas', 'Englestad Street', 0, 4, 0, 0, 0)
# Inserted data: ('2014-11-16', 'Ohio', 'Akron', '1891 E Market St', 1, 4, 0, 0, 1)
# Inserted data: ('2014-11-16', 'Texas', 'El Paso', '115 S. Durango', 0, 5, 0, 1, 0)
# Inserted data: ('2014-11-15', 'Missouri', 'Springfield', '2555 N. Glenstone', 4, 0, 0, 0, 1)
# Inserted data: ('2014-11-15', 'Florida', 'Miami', 'NW 55th and 12th', 1, 3, 0, 0, 0)
# Inserted data: ('2014-11-08', 'California', 'Pomona', '499 E. Arrow Highway', 0, 5, 0, 0, 0)
# Inserted data: ('2014-11-07', 'California', 'Los Angeles', 'East 126th Street and North Compton Avenue', 0, 4, 0, 0, 0)
# Inserted data: ('2014-11-07', 'California', 'Compton', '136th Street', 0, 4, 0, 0, 0)
# Inserted data: ('2014-11-05', 'California', 'San Francisco', '1100 block of Alabama Street', 0, 4, 0, 0, 0)
# Inserted data: ('2014-10-29', 'Tennessee', 'Memphis', 'Yale Road and Ramill Road', 0, 5, 0, 0, 0)
# Inserted data: ('2014-10-26', 'Kentucky', 'Cadiz', '1410 Old Dover Road', 4, 0, 0, 0, 1)
# Inserted data: ('2014-10-24', 'Washington', 'Marysville', '5611 108th St NE', 4, 1, 1, 0, 0)
# Inserted data: ('2014-10-18', 'New York', 'Queens', '33-02 Queens Blvd', 0, 4, 0, 0, 1)
# Inserted data: ('2014-10-18', 'South Carolina', 'Graniteville', '192 Breezy Hill Road', 1, 3, 0, 0, 0)
# Inserted data: ('2014-10-18', 'New York', 'Brooklyn', 'Lenox Road', 0, 4, 0, 0, 0)
# Scraping data for 2014, page 2
# Inserted data: ('2014-10-16', 'Michigan', 'Detroit', 'Mogul Street', 1, 3, 0, 0, 1)
# Inserted data: ('2014-10-14', 'Georgia', 'Peachtree Corners', '6505 Bannor Lane', 2, 2, 1, 0, 0)
# Inserted data: ('2014-10-13', 'Georgia', 'Atlanta', '85 Mount Zion Road', 0, 4, 0, 0, 0)
# Inserted data: ('2014-10-12', 'Georgia', 'Atlanta', 'Arthur Langford Jr Place', 1, 3, 0, 0, 0)
# Inserted data: ('2014-10-12', 'California', 'Stockton', '1100 block of East March Lane', 3, 1, 0, 0, 0)
# Inserted data: ('2014-10-11', 'New York', 'Utica', '222 Bleecker Street', 0, 4, 0, 1, 1)
# Inserted data: ('2014-10-08', 'Georgia', 'Atlanta', 'Auburn Avenue and Edgewood Avenue', 0, 4, 0, 0, 0)
# Inserted data: ('2014-10-08', 'New York', 'Guilderland', '1846 Western Ave', 4, 0, 0, 0, 0)
# Inserted data: ('2014-10-05', 'Michigan', 'Detroit', 'East 7 Mile Road and Sherwood Street', 1, 5, 0, 0, 0)
# Inserted data: ('2014-10-05', 'Florida', 'Jacksonville', '7300 block of Linda Drive', 3, 1, 0, 0, 0)
# Inserted data: ('2014-10-04', 'Tennessee', 'Memphis', '1400 block of Gherald Street', 2, 2, 0, 0, 0)
# Inserted data: ('2014-10-04', 'California', 'Pomona', '1925 West Holt Avenue', 0, 4, 0, 0, 0)
# Inserted data: ('2014-09-29', 'South Carolina', 'Walterboro', '29 Sandy Dam Lane', 1, 6, 0, 1, 2)
# Inserted data: ('2014-09-29', 'California', 'Fresno', '2300 block of West Fountain Way', 0, 4, 0, 0, 0)
# Inserted data: ('2014-09-28', 'Pennsylvania', 'Philadelphia', '2800 block of Hope Street', 0, 4, 0, 0, 0)
# Inserted data: ('2014-09-28', 'Florida', 'Miami', 'NW 7th Ave and NW 64th St', 0, 15, 0, 0, 0)
# Inserted data: ('2014-09-27', 'Missouri', 'Saint Louis', '2000 block East John Avenue', 0, 5, 0, 0, 0)
# Inserted data: ('2014-09-26', 'South Carolina', 'Florence', '650 Turner Rd', 1, 4, 0, 0, 2)
# Inserted data: ('2014-09-21', 'Ohio', 'East Liverpool', '440 First St', 0, 4, 0, 0, 0)
# Inserted data: ('2014-09-20', 'Mississippi', 'Batesville', '8297 Curtis Rd', 2, 2, 0, 0, 0)
# Inserted data: ('2014-09-19', 'New York', 'Queens', '32-14 106th St', 0, 4, 0, 0, 0)
# Inserted data: ('2014-09-18', 'Florida', 'Bell', '2550 NW 29th Terrace', 7, 0, 1, 0, 0)
# Inserted data: ('2014-09-15', 'Louisiana', 'New Orleans', 'Chef Menteur Highway and Dale Street', 0, 5, 0, 0, 0)
# Inserted data: ('2014-09-14', 'Texas', 'Flour Bluff', '229 Naval Air Station Drive', 3, 1, 0, 0, 0)
# Inserted data: ('2014-09-14', 'Texas', 'Corpus Christi', '229 NAS Dr', 3, 1, 0, 0, 1)
# Scraping data for 2014, page 3
# Inserted data: ('2014-09-14', 'Alaska', 'Anchorage', '225 E Fifth', 0, 6, 0, 0, 0)
# Inserted data: ('2014-09-11', 'Michigan', 'Detroit', '14000 block of Patton', 1, 7, 0, 0, 0)
# Inserted data: ('2014-09-06', 'Florida', 'Orlando', '2015 Orange Blossom Trail', 0, 4, 0, 0, 0)
# Inserted data: ('2014-09-06', 'Georgia', 'Macon', '576 Poplar Street', 0, 5, 0, 0, 0)
# Inserted data: ('2014-09-04', 'Michigan', 'Flint', '2400 block of Martin Luther King Boulevard', 0, 5, 0, 0, 0)
# Inserted data: ('2014-09-03', 'California', 'Los Angeles', 'East 27th and Stanford', 0, 6, 0, 0, 0)
# Inserted data: ('2014-09-02', 'Mississippi', 'Jackson', '3622 Medgar Evers Boulevard', 2, 3, 0, 0, 0)
# Inserted data: ('2014-09-02', 'California', 'Highland', '25000 block of Fifth Street', 0, 5, 0, 0, 0)
# Inserted data: ('2014-08-31', 'California', 'Livermore', '200 block of South Q Street', 0, 5, 0, 0, 0)
# Inserted data: ('2014-08-29', 'Florida', 'Brooksville', '820 Peach St', 3, 1, 0, 0, 0)
# Inserted data: ('2014-08-27', 'Michigan', 'Detroit', '16600 block of Edmore', 1, 3, 0, 0, 0)
# Inserted data: ('2014-08-24', 'California', 'San Fernando', '1400 block of Celis Street', 4, 5, 0, 0, 1)
# Inserted data: ('2014-08-24', 'Illinois', 'Chicago', '8300 block of South Halsted Street', 1, 3, 0, 0, 0)
# Inserted data: ('2014-08-24', 'Georgia', 'Augusta', '1013 Carrie Street', 1, 3, 0, 0, 0)
# Inserted data: ('2014-08-20', 'Tennessee', 'Memphis', '1400 block of Briarcrest Lane', 0, 5, 0, 0, 0)
# Inserted data: ('2014-08-18', 'Louisiana', 'Saint Martinville', 'Main and Hyacinth streets', 0, 4, 0, 0, 0)
# Inserted data: ('2014-08-17', 'California', 'East Palo Alto', 'Purdue Street and Georgetown Avenue', 1, 3, 0, 0, 0)
# Inserted data: ('2014-08-17', 'Massachusetts', 'Boston', 'Edinboro Street', 0, 4, 0, 0, 0)
# Inserted data: ('2014-08-17', 'New York', 'Queens', '153-38 118th Ave', 0, 4, 0, 0, 0)
# Inserted data: ('2014-08-17', 'Nevada', 'Las Vegas', 'Owens Avenue and H Street', 0, 4, 0, 0, 0)
# Inserted data: ('2014-08-16', 'Utah', 'Salt Lake City', '122 Pierpont Avenue', 0, 6, 0, 0, 0)
# Inserted data: ('2014-08-16', 'New Jersey', 'Plainfield', 'West 3rd Street and Monroe Avenue', 1, 3, 0, 0, 0)
# Inserted data: ('2014-08-14', 'Tennessee', 'Memphis', '797 Pope Street', 1, 3, 0, 0, 0)
# Inserted data: ('2014-08-13', 'Tennessee', 'Clarksville', 'Treeland Drive', 0, 4, 0, 0, 0)
# Inserted data: ('2014-08-13', 'Louisiana', 'New Orleans', 'New Orleans and North Rocheblave streets', 0, 4, 0, 0, 0)
# Scraping data for 2014, page 4
# Inserted data: ('2014-08-12', 'New York', 'Buffalo', 'Oakmont Ave', 1, 3, 0, 0, 0)
# Inserted data: ('2014-08-12', 'Georgia', 'Cartersville', 'Brent Cir', 1, 3, 1, 0, 0)
# Inserted data: ('2014-08-10', 'Louisiana', 'New Orleans', '5400 block of Burgundy St', 2, 5, 0, 0, 2)
# Inserted data: ('2014-08-10', 'District of Columbia', 'Washington', '50 block of N St SW', 0, 6, 0, 0, 0)
# Inserted data: ('2014-08-10', 'Georgia', 'Wrightsville', '2455 Idylwild Dr', 0, 6, 0, 0, 0)
# Inserted data: ('2014-08-10', 'California', 'Moreno Valley', '16300 block of Heather Glen Road', 0, 7, 0, 0, 0)
# Inserted data: ('2014-08-09', 'Minnesota', 'Minneapolis', '400 3rd Ave N', 1, 8, 0, 0, 0)
# Inserted data: ('2014-08-08', 'District of Columbia', 'Washington', '2nd St NE and Todd Pl NE', 0, 4, 0, 0, 0)
# Inserted data: ('2014-08-08', 'Wisconsin', 'Milwaukee', '3000 block of N. 28th Street', 0, 4, 0, 0, 0)
# Inserted data: ('2014-08-08', 'New Mexico', 'Albuquerque', '3426 Vassar NE', 1, 3, 0, 0, 0)
# Inserted data: ('2014-08-06', 'California', 'Bakersfield', '1700 block of Quincy Street', 3, 1, 0, 0, 0)
# Inserted data: ('2014-08-04', 'Georgia', 'Atlanta', '1100 block of Joseph E. Boone Boulevard NW', 0, 5, 0, 0, 0)
# Inserted data: ('2014-08-03', 'Virginia', 'Culpeper', '14458 Rixeyville Rd', 5, 0, 0, 0, 0)
# Inserted data: ('2014-08-03', 'Texas', 'Humble', '3403 FM 1960', 0, 7, 0, 0, 0)
# Inserted data: ('2014-08-03', 'Missouri', 'Saint Louis', '5200 block of Thekla', 0, 5, 0, 0, 0)
# Inserted data: ('2014-08-03', 'Tennessee', 'Columbia', 'East 9th Street and Bridge Street', 0, 5, 0, 0, 0)
# Inserted data: ('2014-08-02', 'Texas', 'Dallas', '5125 Wynell Street', 3, 1, 0, 0, 1)
# Inserted data: ('2014-08-02', 'Pennsylvania', 'Pittsburgh', 'Penn Avenue and 29th Street', 1, 5, 0, 0, 0)
# Inserted data: ('2014-08-02', 'Massachusetts', 'New Bedford', 'Acushnet Avenue', 0, 7, 0, 0, 0)
# Inserted data: ('2014-08-01', 'Pennsylvania', 'Philadelphia', '1500 block of South Etting Street', 1, 3, 0, 0, 0)
# Inserted data: ('2014-07-30', 'North Carolina', 'Hope Mills', '5109 New Moon Dr', 2, 4, 1, 0, 0)
# Inserted data: ('2014-07-28', 'Pennsylvania', 'Philadelphia', '4900 block of North Front Street', 1, 4, 0, 0, 0)
# Inserted data: ('2014-07-27', 'Missouri', 'Saint Louis', '2000 block of East John Avenue', 0, 5, 0, 0, 0)
# Inserted data: ('2014-07-26', 'Maine', 'Saco', '35 Water Street', 4, 0, 1, 0, 0)
# Inserted data: ('2014-07-26', 'Arkansas', 'Pine Bluff', 'Third Ave and Redbud St', 1, 3, 0, 0, 0)
# Scraping data for 2014, page 5
# Inserted data: ('2014-07-26', 'Georgia', 'Sylvester', 'Royal Street', 0, 8, 0, 0, 0)
# Inserted data: ('2014-07-25', 'Illinois', 'Chicago', '700 S California Ave', 1, 6, 0, 0, 3)
# Inserted data: ('2014-07-23', 'Pennsylvania', 'Braddock', '700 block of Hickory St', 0, 4, 0, 0, 0)
# Inserted data: ('2014-07-21', 'Tennessee', 'Memphis', '300 block of Foote Park Lane', 0, 4, 0, 0, 0)
# Inserted data: ('2014-07-21', 'New Jersey', 'Irvington', '36 Welland Avenue', 0, 6, 0, 0, 0)
# Inserted data: ('2014-07-20', 'Nevada', 'Las Vegas', '3400 block of N Rancho Dr', 1, 3, 0, 0, 0)
# Inserted data: ('2014-07-20', 'Illinois', 'East Saint Louis', '5103 block of Bunkum Rd', 1, 3, 0, 0, 0)
# Inserted data: ('2014-07-19', 'Illinois', 'Chicago', '1300 North Mason Avenue', 0, 4, 0, 0, 0)
# Inserted data: ('2014-07-13', 'District of Columbia', 'Washington', '1700 block of Lincoln Rd NE', 0, 4, 0, 0, 0)
# Inserted data: ('2014-07-13', 'California', 'Sacramento', '1972 Fulton Ave', 1, 4, 0, 0, 0)
# Inserted data: ('2014-07-13', 'Washington', 'Skyway', '12600 Renton Avenue South', 0, 5, 0, 0, 0)
# Inserted data: ('2014-07-13', 'Connecticut', 'Stamford', '84 West Park Place', 0, 5, 0, 0, 0)
# Inserted data: ('2014-07-12', 'California', 'Pasadena', '1700 block of Summit Avenue', 3, 2, 0, 0, 0)
# Inserted data: ('2014-07-11', 'Illinois', 'Chicago', '5200 West Quincy Street', 1, 3, 0, 0, 0)
# Inserted data: ('2014-07-09', 'Texas', 'Spring', '711 Leaflet Ln', 6, 1, 0, 0, 1)
# Inserted data: ('2014-07-08', 'Rhode Island', 'Providence', '35 March Street', 0, 5, 0, 0, 0)
# Inserted data: ('2014-07-07', 'California', 'San Bernardino', '312 E Baseline Street', 1, 4, 0, 0, 0)
# Inserted data: ('2014-07-07', 'Kentucky', 'Stopover', 'KY 194E', 0, 4, 0, 0, 0)
# Inserted data: ('2014-07-06', 'Florida', 'Miami', 'NW 20th Ave and NW 62nd St', 2, 2, 0, 0, 0)
# Inserted data: ('2014-07-06', 'New York', 'Buffalo', '100 block of Erb Street', 0, 4, 0, 0, 0)
# Inserted data: ('2014-07-06', 'Missouri', 'Saint Louis', '4600 block of Natural Bridge Avenue', 0, 4, 0, 0, 0)
# Inserted data: ('2014-07-05', 'Oregon', 'Portland', '333 SE 122nd Ave', 1, 4, 0, 0, 1)
# Inserted data: ('2014-07-05', 'Indiana', 'Indianapolis', 'Broad Ripple Avenue', 0, 7, 0, 0, 0)
# Inserted data: ('2014-07-05', 'Virginia', 'Norfolk', '861 W. 36th Street', 0, 7, 0, 0, 0)
# Inserted data: ('2014-07-05', 'Texas', 'Houston', '1700 Almeda-Genoa', 0, 6, 0, 0, 0)
# Scraping data for 2014, page 6
# Inserted data: ('2014-07-05', 'Illinois', 'Centreville', '4700 Piggott Avenue', 0, 5, 0, 0, 0)
# Inserted data: ('2014-07-04', 'Virginia', 'Norfolk', '1722 Thurgood Street', 0, 5, 0, 0, 0)
# Inserted data: ('2014-07-02', 'Pennsylvania', 'Chester', '1400 block of West Congress Street', 0, 5, 0, 0, 0)
# Inserted data: ('2014-06-30', 'Kentucky', 'Lexington', 'Scottsdale Circle', 1, 3, 0, 0, 1)
# Inserted data: ('2014-06-29', 'Louisiana', 'New Orleans', '700 block of Bourbon St', 1, 9, 0, 0, 1)
# Inserted data: ('2014-06-29', 'Missouri', 'Saint Louis', '2800 block of Dayton', 0, 4, 0, 0, 0)
# Inserted data: ('2014-06-29', 'California', 'Los Angeles', '1100 block of North Vermont Avenue', 1, 5, 0, 0, 1)
# Inserted data: ('2014-06-28', 'California', 'Antioch', '5500 Cedar Point Way', 0, 7, 0, 0, 0)
# Inserted data: ('2014-06-28', 'New York', 'Manhattan', 'Fifth Avenue and West 139th Street', 0, 4, 0, 0, 0)
# Inserted data: ('2014-06-27', 'California', 'San Diego', '1600 block of Cathy Street', 1, 3, 0, 0, 0)
# Inserted data: ('2014-06-26', 'Wisconsin', 'Milwaukee', '24th and Locust', 0, 5, 0, 0, 0)
# Inserted data: ('2014-06-26', 'Michigan', 'Detroit', 'Grand St', 2, 2, 0, 0, 0)
# Inserted data: ('2014-06-25', 'Massachusetts', 'Lowell', 'Midland Street', 0, 5, 0, 0, 0)
# Inserted data: ('2014-06-24', 'Florida', 'Miami', 'Northwest 12th Avenue and 65th Street', 2, 7, 0, 0, 0)
# Inserted data: ('2014-06-22', 'California', 'Windsor', 'Windsor Avenue', 1, 3, 0, 0, 0)
# Inserted data: ('2014-06-21', 'Tennessee', 'Memphis', '2119 East Alcy Road', 0, 5, 0, 0, 7)
# Inserted data: ('2014-06-21', 'District of Columbia', 'Washington', 'Florida Ave NW and U St NW', 0, 4, 0, 0, 0)
# Inserted data: ('2014-06-20', 'Maryland', 'Seat Pleasant', '6600 block of Greig Street', 0, 4, 0, 0, 0)
# Inserted data: ('2014-06-15', 'Indiana', 'Kokomo', '5100 Clinton Drive', 0, 4, 0, 0, 0)
# Inserted data: ('2014-06-15', 'Illinois', 'Park Forest', '200 Berry Street', 0, 4, 0, 0, 0)
# Inserted data: ('2014-06-13', 'California', 'Los Angeles', '8600 block of South Figueroa Street', 3, 1, 0, 0, 0)
# Inserted data: ('2014-06-09', 'New Jersey', 'Paterson', 'Rosa Parks Boulevard and Godwin Avenue', 0, 6, 0, 0, 0)
# Inserted data: ('2014-06-08', 'Florida', 'Fort Myers', '17372 Phlox Drive', 4, 0, 1, 0, 0)
# Inserted data: ('2014-06-08', 'Alabama', 'Opp', '611 Hardin Street', 1, 4, 0, 0, 1)
# Inserted data: ('2014-06-07', 'South Carolina', 'Moncks Corner', 'Tish Lane', 1, 5, 0, 0, 0)
# Scraping data for 2014, page 7
# Inserted data: ('2014-06-07', 'Michigan', 'Oak Park', '10811 W. Ten Mile Rd.', 1, 3, 0, 0, 0)
# Inserted data: ('2014-06-04', 'Illinois', 'Chicago', '4900 West West End Avenue', 1, 3, 0, 0, 0)
# Inserted data: ('2014-06-03', 'Georgia', 'Atlanta', 'Auburn Avenue', 1, 4, 0, 0, 1)
# Inserted data: ('2014-06-02', 'Illinois', 'Chicago', '2660 E. 79th St', 0, 7, 0, 0, 0)
# Inserted data: ('2014-06-01', 'California', 'Sacramento', '6500 46th Street', 0, 4, 0, 0, 0)
# Inserted data: ('2014-06-01', 'Illinois', 'Chicago', 'West Ferdinand Street and North Lavergne Avenue', 1, 5, 0, 0, 0)
# Inserted data: ('2014-05-31', 'California', 'San Bernardino', '800 block of West Victoria St', 1, 3, 0, 0, 0)
# Inserted data: ('2014-05-25', 'Ohio', 'Toledo', '2100 block of Joffre Avenue', 1, 3, 0, 0, 0)
# Inserted data: ('2014-05-24', 'Michigan', 'Detroit', 'Strathmoor St', 0, 4, 0, 0, 0)
# Inserted data: ('2014-05-24', 'South Carolina', 'Myrtle Beach', '104 N Ocean Blvd', 3, 1, 0, 0, 0)
# Inserted data: ('2014-05-23', 'Louisiana', 'New Orleans', '6200 block of Eads Street', 1, 7, 0, 0, 0)
# Inserted data: ('2014-05-23', 'California', 'Goleta', '840 Embarcadero del Norte', 3, 7, 1, 0, 0)
# Inserted data: ('2014-05-23', 'California', 'Bellflower', '9541 Flower Street', 2, 2, 0, 0, 0)
# Inserted data: ('2014-05-21', 'Texas', 'Dallas', '4515 Village Fair Pl', 1, 3, 0, 0, 0)
# Inserted data: ('2014-05-18', 'Ohio', 'Sandusky', '1643 Cleveland Rd', 0, 7, 0, 0, 0)
# Inserted data: ('2014-05-17', 'California', 'Coachella', '84000 block of Pedro Drive', 1, 3, 0, 0, 1)
# Inserted data: ('2014-05-17', 'District of Columbia', 'Washington', '2200 block of Adams Pl NE', 0, 5, 0, 0, 0)
# Inserted data: ('2014-05-13', 'Georgia', 'Atlanta', 'Panther Trail and Childress Drive', 0, 5, 0, 0, 0)
# Inserted data: ('2014-05-12', 'Illinois', 'Chicago', '3400 West 24th Street', 0, 4, 0, 0, 0)
# Inserted data: ('2014-05-11', 'Tennessee', 'Memphis', '2517 Shasta', 0, 7, 0, 0, 0)
# Inserted data: ('2014-05-10', 'California', 'Sacramento', '3031 Guadalajara Way', 1, 6, 0, 0, 2)
# Inserted data: ('2014-05-10', 'Georgia', 'Stone Mountain', '1100 To Lani Farm Road', 1, 3, 0, 0, 1)
# Inserted data: ('2014-05-10', 'Georgia', 'Decatur', 'Shamrock Dr', 2, 3, 0, 0, 1)
# Inserted data: ('2014-05-04', 'Colorado', 'Wheat Ridge', '12100 W 44th', 0, 4, 0, 0, 0)
# Inserted data: ('2014-05-04', 'Illinois', 'Chicago', '500 West Erie Street', 1, 3, 0, 0, 0)
# Scraping data for 2014, page 8
# Inserted data: ('2014-05-03', 'Arkansas', 'Jonesboro', '2201 Moore Rd', 3, 4, 1, 0, 0)
# Inserted data: ('2014-05-03', 'Texas', 'Houston', 'Gears Rd and Trickey Rd', 0, 6, 0, 0, 0)
# Inserted data: ('2014-04-30', 'Illinois', 'Chicago', '7200 South Phillips Avenue', 0, 4, 0, 0, 0)
# Inserted data: ('2014-04-29', 'Georgia', 'Kennesaw', '1675 Airport Road', 0, 6, 1, 0, 0)
# Inserted data: ('2014-04-27', 'New York', 'Troy', 'Fourth Street', 0, 5, 0, 0, 0)
# Inserted data: ('2014-04-25', 'Tennessee', 'Memphis', '2000 Chelsea Avenue', 2, 3, 0, 0, 0)
# Inserted data: ('2014-04-22', 'California', 'Los Angeles', '6419 Brynhurst Avenue', 1, 3, 0, 0, 0)
# Inserted data: ('2014-04-20', 'Illinois', 'Montgomery', '1300 block of Jackson St', 0, 6, 0, 0, 0)
# Inserted data: ('2014-04-20', 'Illinois', 'Chicago', '6600 South Michigan Ave', 0, 5, 0, 0, 0)
# Inserted data: ('2014-04-20', 'Florida', 'Tampa', '2902 N. 32nd St.', 2, 2, 0, 0, 0)
# Inserted data: ('2014-04-14', 'District of Columbia', 'Washington', '1909 19th St SE', 0, 4, 0, 0, 0)
# Inserted data: ('2014-04-12', 'Louisiana', 'New Orleans', '2100 block of Pauger Street', 1, 3, 0, 0, 0)
# Inserted data: ('2014-04-11', 'Indiana', 'Richmond', 'North 15th and H Streets', 0, 4, 0, 0, 0)
# Inserted data: ('2014-04-09', 'Illinois', 'Rockford', '300 N Sunset Ave', 0, 5, 0, 0, 0)
# Inserted data: ('2014-04-09', 'Tennessee', 'Lookout Valley', 'Kellys Ferry Road and Kellys Ferry Place', 3, 1, 0, 0, 0)
# Inserted data: ('2014-04-07', 'Louisiana', 'New Orleans', '500 block of South Alexander Street', 0, 4, 0, 0, 0)
# Inserted data: ('2014-04-06', 'Massachusetts', 'Springfield', '90 Worthington St.', 0, 4, 0, 0, 0)
# Inserted data: ('2014-04-06', 'Oklahoma', 'Oklahoma City', 'Northwest 29th Street and Portland Avenue', 0, 4, 0, 0, 0)
# Inserted data: ('2014-04-05', 'Illinois', 'Chicago', '4300 W Wilcox Street', 1, 5, 0, 0, 0)
# Inserted data: ('2014-04-05', 'Arizona', 'Phoenix', '5400 block of W Palm Ln', 1, 3, 0, 0, 0)
# Inserted data: ('2014-04-05', 'California', 'Fairfield', 'Orchid Street', 0, 4, 0, 0, 0)
# Inserted data: ('2014-04-02', 'Texas', 'Fort Hood', 'Motor Pool Road and Tank Destroyer Boulevard', 3, 16, 1, 0, 0)
# Inserted data: ('2014-03-30', 'Mississippi', 'Starkville', '2938 Rockhill Rd', 0, 5, 0, 0, 1)
# Inserted data: ('2014-03-30', 'North Carolina', 'Charlotte', '4300 Sunset Road', 0, 5, 0, 0, 0)
# Inserted data: ('2014-03-23', 'Texas', 'Arlington', '2700 Majesty Drive', 1, 3, 0, 0, 0)
# Scraping data for 2014, page 9
# Inserted data: ('2014-03-23', 'California', 'Long Beach', '601 Long Beach Boulevard', 1, 3, 0, 0, 0)
# Inserted data: ('2014-03-23', 'California', 'San Francisco', 'Turk and Taylor', 0, 7, 0, 0, 0)
# Inserted data: ('2014-03-21', 'South Carolina', 'North Charleston', '7550 Dorchester Road', 0, 4, 0, 0, 0)
# Inserted data: ('2014-03-16', 'Texas', 'Beaumont', 'S 4th St', 3, 1, 0, 0, 1)
# Inserted data: ('2014-03-16', 'Georgia', 'Waynesboro', '4960 Highway 80 West', 0, 4, 0, 0, 0)
# Inserted data: ('2014-03-14', 'New York', 'Brooklyn', 'S. Second and Roebling Sts', 0, 4, 0, 0, 0)
# Inserted data: ('2014-03-09', 'Ohio', 'Fremont', '531 W State St', 3, 1, 0, 0, 0)
# Inserted data: ('2014-03-09', 'Texas', 'Austin', '4900 block of West Race Avenue', 0, 6, 0, 0, 0)
# Inserted data: ('2014-03-08', 'California', 'Richmond', '1600 block of First Street', 1, 3, 0, 0, 0)
# Inserted data: ('2014-03-08', 'Illinois', 'Chicago', '4900 West Race Ave', 0, 6, 0, 0, 0)
# Inserted data: ('2014-03-05', 'South Carolina', 'Pelzer', 'Law St', 3, 1, 0, 0, 1)
# Inserted data: ('2014-03-01', 'Pennsylvania', 'Pittsburgh', 'Hamilton Ave', 1, 4, 0, 0, 1)
# Inserted data: ('2014-02-25', 'Virginia', 'Glade Spring', '33325 Graceland Ln', 3, 1, 1, 0, 0)
# Inserted data: ('2014-02-22', 'California', 'Wilmington', '1200 block of W Papeete St', 0, 4, 0, 0, 0)
# Inserted data: ('2014-02-20', 'California', 'Alturas', '300 W 1st St', 4, 1, 0, 0, 1)
# Inserted data: ('2014-02-20', 'Indiana', 'Indianapolis', '3200 block of S Parker Ave', 4, 0, 0, 0, 1)
# Inserted data: ('2014-02-16', 'Florida', 'Orlando (Pine Hills)', '4500 block of Charlene Terrace', 1, 6, 0, 0, 0)
# Inserted data: ('2014-02-16', 'Texas', 'Fort Worth', '115 NW 25th St.', 1, 4, 0, 0, 0)
# Inserted data: ('2014-02-16', 'Indiana', 'Fort Wayne', 'Lafayette Street and East Tillman Road', 0, 5, 0, 0, 0)
# Inserted data: ('2014-02-16', 'Texas', 'Dallas', '2600 block of South Harwood Street', 1, 7, 0, 0, 0)
# Inserted data: ('2014-02-16', 'Florida', 'Jacksonville', '1187 S. Edgewood Ave.', 1, 4, 0, 0, 0)
# Inserted data: ('2014-02-15', 'Nevada', 'Las Vegas', 'Sahara and Maryland', 0, 5, 0, 0, 0)
# Inserted data: ('2014-02-12', 'California', 'Stockton', '1101 E Lindsay St', 1, 3, 0, 0, 0)
# Inserted data: ('2014-02-12', 'Indiana', 'Gary', '2220 block of Broadway', 0, 4, 0, 1, 0)
# Inserted data: ('2014-02-12', 'California', 'Oakland', '37th and International', 1, 3, 0, 0, 0)
# Scraping data for 2014, page 10
# Inserted data: ('2014-02-07', 'Florida', 'Miami', 'Northwest 41st Street and 9th Avenue', 0, 5, 0, 0, 0)
# Inserted data: ('2014-02-06', 'Louisiana', 'New Orleans', '4600 block of Downman Road', 0, 4, 0, 0, 0)
# Inserted data: ('2014-02-05', 'Illinois', 'Chicago', '6740 N Clark St', 1, 3, 0, 0, 0)
# Inserted data: ('2014-02-03', 'Indiana', 'Franklin', '2100 block of Bridlewood Dr', 2, 2, 1, 0, 0)
# Inserted data: ('2014-01-30', 'Texas', 'Cypress', '14015 Fosters Creek Dr', 4, 0, 0, 0, 1)
# Inserted data: ('2014-01-27', 'North Carolina', 'Rocky Mount', '821 Word Plaza', 0, 4, 0, 0, 1)
# Inserted data: ('2014-01-27', 'Washington', 'Seattle', '2nd Avenue South and South Main Street', 1, 4, 0, 0, 1)
# Inserted data: ('2014-01-25', 'Illinois', 'Chicago', 'S Union Ave and W 51st St', 1, 4, 0, 0, 0)
# Inserted data: ('2014-01-25', 'Florida', 'Belle Glade', '600 block of Covenant Drive', 0, 4, 0, 0, 0)
# Inserted data: ('2014-01-21', 'New Jersey', 'Newark', 'Springfield Avenue', 2, 3, 0, 0, 0)
# Inserted data: ('2014-01-20', 'Virginia', 'Manassas', '8509 Rixlew Ln', 0, 4, 0, 0, 0)
# Inserted data: ('2014-01-16', 'Oklahoma', 'Ardmore', 'H St NE and Martin Luther King Blvd', 1, 4, 1, 0, 0)
# Inserted data: ('2014-01-16', 'Utah', 'Spanish Fork', '37 N 630 West', 4, 0, 1, 0, 0)
# Inserted data: ('2014-01-14', 'California', 'Los Angeles', 'West 86th Street', 0, 4, 0, 0, 0)
# Inserted data: ('2014-01-13', 'Michigan', 'Detroit', '800 block of Calvert St', 0, 4, 0, 0, 0)
# Inserted data: ('2014-01-12', 'Illinois', 'Elgin', '300 block of North St', 0, 5, 0, 0, 0)
# Inserted data: ('2014-01-12', 'Louisiana', 'Tallulah', '3600 block of Highway 80 W', 0, 6, 0, 0, 8)
# Inserted data: ('2014-01-12', 'Alabama', 'Huntsville', 'University Drive', 0, 5, 0, 0, 0)
# Inserted data: ('2014-01-11', 'Mississippi', 'Jackson', '3430 W. Capitol Street', 0, 4, 0, 0, 0)
# Inserted data: ('2014-01-05', 'Pennsylvania', 'Erie', '829 Parade St', 1, 3, 0, 0, 0)
# Inserted data: ('2014-01-03', 'New York', 'Queens', 'Farmers Boulevard and 133rd Avenue', 1, 3, 0, 0, 0)
# Inserted data: ('2014-01-01', 'Virginia', 'Norfolk', 'Rockingham Street and Berkley Avenue Extended', 2, 2, 0, 0, 0)
# Scraping data for 2015, page 0
# Inserted data: ('2015-12-31', 'Louisiana', 'New Orleans', '1900 block of Amelia Street', 0, 5, 0, 1, 1)
# Inserted data: ('2015-12-27', 'Tennessee', 'Jackson', 'North Parkway', 0, 4, 0, 0, 0)
# Inserted data: ('2015-12-26', 'Pennsylvania', 'Philadelphia', '4210 Macalester St', 0, 4, 0, 0, 2)
# Inserted data: ('2015-12-25', 'Florida', 'Jacksonville', 'Franklin and Odessa', 0, 4, 0, 0, 0)
# Inserted data: ('2015-12-25', 'Alabama', 'Mobile', '785 Schillinger Rd S', 0, 4, 0, 0, 0)
# Inserted data: ('2015-12-21', 'California', 'San Leandro', '14600 block of East 14th Street', 0, 4, 0, 0, 2)
# Inserted data: ('2015-12-20', 'North Carolina', 'Wilmington', '11th and Castle Street', 1, 4, 0, 0, 0)
# Inserted data: ('2015-12-20', 'Florida', 'North Miami Beach', 'NE 167th St and NE 6th Ave', 0, 4, 0, 0, 0)
# Inserted data: ('2015-12-19', 'Florida', 'Miami', '21630 SW 120th Ave', 1, 4, 0, 0, 0)
# Inserted data: ('2015-12-13', 'California', 'Los Angeles', '5550 S. Flower Street', 1, 3, 0, 0, 0)
# Inserted data: ('2015-12-13', 'California', 'Huntington Beach', '17000 block of Keelson Lane', 0, 4, 0, 0, 0)
# Inserted data: ('2015-12-12', 'Illinois', 'Lovejoy (Brooklyn)', '307 Jefferson St', 1, 3, 0, 0, 1)
# Inserted data: ('2015-12-12', 'Georgia', 'Savannah', 'Whitaker Street', 0, 4, 0, 0, 1)
# Inserted data: ('2015-12-11', 'Maryland', 'Baltimore', '5100 block of Park Heights Avenue', 1, 3, 0, 0, 0)
# Inserted data: ('2015-12-11', 'Pennsylvania', 'Pittsburgh', '1222 Brownsville Rd', 0, 4, 0, 0, 0)
# Inserted data: ('2015-12-08', 'Ohio', 'Cincinnati', '2300 block of Baltimore Ave', 1, 3, 0, 0, 1)
# Inserted data: ('2015-12-06', 'Louisiana', 'Raceland', 'Market Street', 1, 3, 0, 0, 2)
# Inserted data: ('2015-12-06', 'Nebraska', 'Omaha', 'North 108th Street and Military Road', 2, 3, 0, 0, 1)
# Inserted data: ('2015-12-02', 'California', 'San Bernardino', '1365 South Waterman Ave', 14, 19, 2, 0, 0)
# Inserted data: ('2015-12-02', 'Georgia', 'Savannah', '100 block of West 33rd Street', 1, 3, 0, 0, 0)
# Inserted data: ('2015-11-29', 'Illinois', 'Kankakee', '648 E Court St', 0, 5, 0, 0, 0)
# Inserted data: ('2015-11-27', 'Colorado', 'Colorado Springs', '3480 Centennial Blvd', 3, 9, 0, 0, 1)
# Inserted data: ('2015-11-27', 'California', 'Sacramento', '7900 block of Florin Road', 2, 2, 0, 0, 0)
# Inserted data: ('2015-11-24', 'South Carolina', 'Conway', '1321 Colletta Ct', 0, 4, 0, 0, 0)
# Inserted data: ('2015-11-23', 'Minnesota', 'Minneapolis', 'Morgan Avenue North', 0, 5, 0, 0, 4)
# Scraping data for 2015, page 1
# Inserted data: ('2015-11-23', 'Ohio', 'Columbus', '90 block of S Terrace Ave', 3, 1, 1, 0, 0)
# Inserted data: ('2015-11-22', 'New York', 'Newburgh', '203 Broadway', 0, 5, 0, 0, 0)
# Inserted data: ('2015-11-22', 'South Carolina', 'North Charleston', 'Park Circle', 1, 3, 0, 0, 1)
# Inserted data: ('2015-11-22', 'Illinois', 'Chicago', '4100 block of West Roosevelt', 0, 4, 0, 0, 0)
# Inserted data: ('2015-11-22', 'Louisiana', 'New Orleans', '1900 block of Gallier St', 0, 17, 0, 0, 9)
# Inserted data: ('2015-11-22', 'Washington', 'Seattle', 'Broadway and Pike', 0, 4, 0, 0, 2)
# Inserted data: ('2015-11-22', 'Texas', 'Brownsville', '1800 block of FM 802', 0, 4, 0, 0, 1)
# Inserted data: ('2015-11-21', 'Maryland', 'Baltimore', 'Stricker and School', 1, 3, 0, 0, 0)
# Inserted data: ('2015-11-20', 'Pennsylvania', 'Pittsburgh', 'Prospect Drive', 1, 3, 0, 0, 0)
# Inserted data: ('2015-11-18', 'California', 'Fresno', 'California Avenue and Martin Luther King Jr. Boulevard', 0, 5, 0, 0, 0)
# Inserted data: ('2015-11-16', 'Alabama', 'Cedar Bluff', '1460 County Rd 664', 3, 1, 0, 0, 1)
# Inserted data: ('2015-11-15', 'Texas', 'Tennessee Colony', '800 block of An County Rd 2217', 5, 0, 0, 0, 1)
# Inserted data: ('2015-11-15', 'Pennsylvania', 'Philadelphia', '5600 block of Blakemore St', 0, 4, 0, 0, 0)
# Inserted data: ('2015-11-14', 'Pennsylvania', 'Johnstown', '1159 Main St', 0, 4, 0, 0, 0)
# Inserted data: ('2015-11-13', 'Florida', 'Jacksonville', '1300 block of South Shirley Oaks Drive', 3, 1, 1, 0, 0)
# Inserted data: ('2015-11-09', 'Indiana', 'Indianapolis', '400 block of North Beville Ave', 2, 2, 0, 0, 3)
# Inserted data: ('2015-11-08', 'Iowa', 'Des Moines', '4397 NW 6th Drive', 1, 3, 0, 0, 1)
# Inserted data: ('2015-11-08', 'Michigan', 'Warren', '13859 8 Mile Road', 0, 4, 0, 0, 0)
# Inserted data: ('2015-11-07', 'Colorado', 'Denver', 'Bayaud and Bannock', 1, 3, 0, 0, 1)
# Inserted data: ('2015-11-06', 'California', 'Bakersfield', '1000 block of Feliz Drive', 0, 4, 0, 0, 0)
# Inserted data: ('2015-11-03', 'Florida', 'Jacksonville', 'Ella Street and Kings Road', 2, 3, 0, 0, 0)
# Inserted data: ('2015-10-28', 'Louisiana', 'Houma', '400 block of Morgan Street', 1, 3, 0, 0, 2)
# Inserted data: ('2015-10-27', 'Texas', 'Fort Worth', '1700 block of Southcrest Drive', 0, 5, 0, 0, 0)
# Inserted data: ('2015-10-25', 'Arizona', 'Phoenix', 'Seventh Street and Broadway', 1, 4, 0, 0, 0)
# Inserted data: ('2015-10-25', 'District of Columbia', 'Washington', '4300 block of Wheeler Road SE', 0, 5, 0, 0, 0)
# Scraping data for 2015, page 2
# Inserted data: ('2015-10-25', 'North Carolina', 'Four Oaks', '2339 Stricklands Crossroads Road', 0, 5, 0, 0, 0)
# Inserted data: ('2015-10-24', 'South Carolina', 'Bamberg', '682 Dixie Ave.', 0, 4, 0, 0, 0)
# Inserted data: ('2015-10-22', 'Tennessee', 'Nashville', '3500 John A. Merritt Blvd', 1, 3, 0, 0, 2)
# Inserted data: ('2015-10-19', 'Illinois', 'Calumet City', '300 Campbell Avenue', 0, 6, 0, 0, 0)
# Inserted data: ('2015-10-18', 'Louisiana', 'New Orleans', '2600 block of Caffin Avenue', 0, 4, 0, 0, 0)
# Inserted data: ('2015-10-17', 'Florida', 'Fort Myers', '2224 First St', 1, 4, 0, 0, 1)
# Inserted data: ('2015-10-17', 'Indiana', 'Elkhart', '160 Easy Shopping Pl', 0, 4, 0, 0, 0)
# Inserted data: ('2015-10-12', 'Georgia', 'Decatur', '4731 Glenwood Road', 0, 4, 0, 0, 0)
# Inserted data: ('2015-10-10', 'Tennessee', 'Memphis', '6135 Mount Moriah Road', 0, 6, 0, 0, 0)
# Inserted data: ('2015-10-10', 'North Carolina', 'Charlotte', '1900 block of West Boulevard', 0, 4, 0, 0, 0)
# Inserted data: ('2015-10-10', 'Illinois', 'Peoria', '2405 N Flora', 1, 3, 0, 0, 6)
# Inserted data: ('2015-10-09', 'Arizona', 'Flagstaff', '216 E Mountain View Dr', 1, 3, 0, 0, 1)
# Inserted data: ('2015-10-06', 'Maryland', 'Baltimore', '300 block of North Payson Street', 0, 5, 0, 0, 0)
# Inserted data: ('2015-10-02', 'Maryland', 'Baltimore', '5400 Reisterstown Road', 1, 4, 0, 0, 0)
# Inserted data: ('2015-10-01', 'Oregon', 'Roseburg', '1140 Umpqua College Rd', 9, 9, 1, 0, 0)
# Inserted data: ('2015-09-28', 'Illinois', 'Chicago', '300 block of West 42nd Street', 3, 2, 0, 0, 3)
# Inserted data: ('2015-09-28', 'Illinois', 'Chicago', '5300 block of South Aberdeen Street', 2, 3, 0, 0, 0)
# Inserted data: ('2015-09-28', 'Ohio', 'Dayton', '1921 Oakridge', 0, 4, 0, 0, 0)
# Inserted data: ('2015-09-28', 'Ohio', 'Cincinnati', '1800 block of Hewitt Ave', 0, 5, 0, 0, 1)
# Inserted data: ('2015-09-27', 'Georgia', 'Greenville', '1140 Hill Haven Road', 0, 10, 0, 0, 2)
# Inserted data: ('2015-09-27', 'Illinois', 'Chicago', '5200 block of South Justine', 0, 4, 0, 0, 0)
# Inserted data: ('2015-09-27', 'Missouri', 'Kansas City', '1700 E. 18th St.', 0, 4, 0, 0, 0)
# Inserted data: ('2015-09-25', 'Illinois', 'Danville', '1300 block of May Street', 0, 4, 0, 0, 0)
# Inserted data: ('2015-09-24', 'Illinois', 'Chicago', '5100 block of South Morgan Street', 0, 5, 0, 0, 0)
# Inserted data: ('2015-09-23', 'Florida', 'Fort Myers', 'Dale St and Veronica S. Shoemaker Blvd', 0, 4, 0, 0, 0)
# Scraping data for 2015, page 3
# Inserted data: ('2015-09-23', 'Louisiana', 'Shreveport', '2900 block of Peach Street', 0, 5, 0, 0, 0)
# Inserted data: ('2015-09-23', 'Georgia', 'Norcross', '1300 block of Reddington Lane', 1, 3, 0, 0, 1)
# Inserted data: ('2015-09-20', 'Oklahoma', 'Tulsa', 'Pine and Yale', 0, 6, 0, 0, 0)
# Inserted data: ('2015-09-20', 'Pennsylvania', 'Philadelphia', '900 Pratt St', 1, 3, 0, 0, 0)
# Inserted data: ('2015-09-20', 'Illinois', 'Chicago', '5700 block of South LaSalle', 1, 5, 0, 0, 0)
# Inserted data: ('2015-09-19', 'Indiana', 'Indianapolis', '3900 block of Graceland Ave', 1, 3, 0, 0, 0)
# Inserted data: ('2015-09-17', 'South Dakota', 'Geddes', '36705 379th Street', 5, 0, 1, 0, 0)
# Inserted data: ('2015-09-17', 'Michigan', 'Albion', '500 block of W. Broadwell Street', 0, 4, 0, 0, 0)
# Inserted data: ('2015-09-15', 'New Jersey', 'Newark', 'Irvine Turner Boulevard and West Kinney Street', 0, 4, 0, 0, 0)
# Inserted data: ('2015-09-13', 'Florida', 'Ocala', '1910 South Pine Avenue', 1, 5, 0, 0, 3)
# Inserted data: ('2015-09-12', 'Louisiana', 'Shreveport', '1500 block of Clanton Street', 0, 4, 0, 0, 0)
# Inserted data: ('2015-09-12', 'New York', 'Rochester', '36 Woodward Street', 2, 3, 0, 1, 1)
# Inserted data: ('2015-09-12', 'Minnesota', 'Minneapolis', '1st Ave. and N. 5th St.', 0, 6, 0, 0, 3)
# Inserted data: ('2015-09-12', 'Minnesota', 'Minneapolis', '1200 block of 22nd Ave. N.', 1, 3, 0, 0, 0)
# Inserted data: ('2015-09-11', 'North Carolina', 'Charlotte', '1000 North Carolina Music Factory Blvd.', 0, 4, 0, 1, 2)
# Inserted data: ('2015-09-08', 'Illinois', 'Chicago', '56th and Green', 0, 4, 0, 0, 0)
# Inserted data: ('2015-09-08', 'Georgia', 'Berlin', 'N/A', 0, 4, 0, 0, 1)
# Inserted data: ('2015-09-07', 'Indiana', 'Gary', '9300 block of Sunrise', 2, 4, 0, 0, 0)
# Inserted data: ('2015-09-07', 'Colorado', 'Denver', '1909 Blake Street', 0, 4, 0, 0, 0)
# Inserted data: ('2015-09-07', 'Minnesota', 'Excelsior', 'Channel Drive', 4, 0, 1, 0, 0)
# Inserted data: ('2015-09-05', 'North Carolina', 'Charlotte', '6800 block of Fieldvale Place', 1, 3, 0, 0, 0)
# Inserted data: ('2015-09-05', 'Florida', 'Daytona Beach', '300 block of Pearl Street', 0, 4, 0, 0, 0)
# Inserted data: ('2015-09-05', 'Nevada', 'Las Vegas', '5000 block of Hollywood Boulevard', 1, 3, 0, 0, 0)
# Inserted data: ('2015-09-05', 'Missouri', 'Columbia', '1509 Ashley Street', 0, 4, 0, 0, 1)
# Inserted data: ('2015-08-30', 'Tennessee', 'Memphis', '3300 block of Sobota Circle', 1, 4, 0, 0, 0)
# Scraping data for 2015, page 4
# Inserted data: ('2015-08-29', 'Tennessee', 'Bristol', '618 Henson Road', 3, 1, 0, 1, 1)
# Inserted data: ('2015-08-29', 'Texas', 'Tyler', '638 ENE Loop 323', 1, 3, 0, 0, 4)
# Inserted data: ('2015-08-28', 'New York', 'Brooklyn', '589 Flatbush Avenue', 1, 3, 0, 0, 1)
# Inserted data: ('2015-08-27', 'Florida', 'Saint Augustine', 'S Bellagio Dr', 2, 2, 0, 0, 1)
# Inserted data: ('2015-08-27', 'California', 'Salinas', '928 Blanco Circle', 2, 2, 0, 0, 1)
# Inserted data: ('2015-08-26', 'Minnesota', 'Minneapolis (Brooklyn Center)', '5000 block of Drew Ave N', 0, 4, 0, 0, 0)
# Inserted data: ('2015-08-26', 'Illinois', 'Chicago', '3025 W. Van Buren Ave', 2, 2, 0, 0, 1)
# Inserted data: ('2015-08-26', 'Florida', 'West Palm Beach', '800 block of 19th Street', 2, 2, 0, 0, 0)
# Inserted data: ('2015-08-25', 'Louisiana', 'New Orleans', 'Fern Street and Olive Street', 1, 3, 0, 0, 0)
# Inserted data: ('2015-08-23', 'California', 'Modesto', '1100 block of Kansas Avenue', 1, 7, 0, 0, 0)
# Inserted data: ('2015-08-22', 'New Mexico', 'Roswell', '302 East Reed Street', 3, 1, 0, 0, 0)
# Inserted data: ('2015-08-22', 'Florida', 'Orlando', 'FL-408 and N Pine Hills Rd', 0, 4, 0, 0, 0)
# Inserted data: ('2015-08-21', 'North Carolina', 'Durham', '2700 block of Hinson Drive', 0, 8, 0, 0, 0)
# Inserted data: ('2015-08-21', 'Ohio', 'Cincinnati', 'Mathis and Prentice', 1, 5, 1, 0, 0)
# Inserted data: ('2015-08-19', 'New York', 'Rochester', '500 Genesee St', 3, 3, 0, 0, 3)
# Inserted data: ('2015-08-16', 'Texas', 'Fort Worth', '3651 Sycamore School Rd', 0, 6, 0, 0, 0)
# Inserted data: ('2015-08-16', 'Illinois', 'Chicago', '5400 block of West Division Street', 0, 4, 0, 0, 0)
# Inserted data: ('2015-08-16', 'South Carolina', 'Bennettsville', 'Highway 38N', 0, 5, 0, 0, 1)
# Inserted data: ('2015-08-15', 'Pennsylvania', 'Pittsburgh', 'West Prospect Avenue', 1, 3, 0, 0, 0)
# Inserted data: ('2015-08-15', 'California', 'Los Angeles', '57th Street and South Normandie Avenue', 0, 4, 0, 0, 0)
# Inserted data: ('2015-08-15', 'South Carolina', 'Orangeburg', '2868 Bamberg Road', 1, 3, 0, 0, 1)
# Inserted data: ('2015-08-10', 'California', 'Long Beach', '1700 block of East 10th Street', 0, 4, 0, 0, 0)
# Inserted data: ('2015-08-09', 'Mississippi', 'Forest', 'Poplar St', 1, 3, 0, 0, 2)
# Inserted data: ('2015-08-09', 'Michigan', 'Detroit', '15200 block of Hazelridge', 1, 3, 0, 0, 0)
# Inserted data: ('2015-08-09', 'Missouri', 'Kansas City', '40th Street and Pennsylvania Avenue', 0, 4, 0, 0, 0)
# Scraping data for 2015, page 5
# Inserted data: ('2015-08-08', 'North Carolina', 'Gastonia', '4908 Greenwood Dr', 1, 3, 1, 0, 0)
# Inserted data: ('2015-08-08', 'Arkansas', 'Blytheville', '833 Anderson Street', 1, 11, 0, 0, 1)
# Inserted data: ('2015-08-08', 'Texas', 'Houston', '2211 Falling Oaks', 8, 0, 0, 0, 1)
# Inserted data: ('2015-08-07', 'Vermont', 'Barre', '3182 Airport Rd', 4, 0, 0, 0, 1)
# Inserted data: ('2015-08-06', 'South Carolina', 'Columbia', '1505 Garden Plaza', 0, 4, 0, 0, 0)
# Inserted data: ('2015-08-04', 'Missouri', 'Saint Louis', '2500 block of Semple', 1, 4, 0, 0, 0)
# Inserted data: ('2015-08-03', 'New York', 'Brooklyn', '98 Dwight Street', 0, 5, 0, 0, 4)
# Inserted data: ('2015-08-02', 'New York', 'Brooklyn', 'Stanley Avenue and Crescent Street', 0, 9, 0, 0, 0)
# Inserted data: ('2015-08-02', 'Maryland', 'Baltimore', '2700 block of Garrison Avenue', 0, 7, 0, 0, 0)
# Inserted data: ('2015-08-02', 'Illinois', 'Chicago', '4800 block of West Kamerling Avenue', 1, 4, 0, 0, 0)
# Inserted data: ('2015-08-02', 'Georgia', 'Savannah', 'Barnard Street', 0, 5, 0, 0, 0)
# Inserted data: ('2015-08-02', 'Illinois', 'Chicago', '6700 block of South Winchester Avenue', 0, 4, 0, 0, 0)
# Inserted data: ('2015-08-01', 'Florida', 'Orlando', '5801 Shenandoah Way', 0, 4, 0, 0, 0)
# Inserted data: ('2015-07-30', 'Pennsylvania', 'Pittsburgh', 'Brushton Avenue', 0, 4, 0, 0, 0)
# Inserted data: ('2015-07-27', 'Illinois', 'Rockford', '900 block of Kent Street', 0, 5, 0, 0, 0)
# Inserted data: ('2015-07-26', 'Missouri', 'Kansas City', 'Thompson and Colorado', 2, 3, 0, 0, 0)
# Inserted data: ('2015-07-26', 'Louisiana', 'New Orleans', 'Piety and Treasure street', 0, 4, 0, 0, 0)
# Inserted data: ('2015-07-25', 'Virginia', 'Hopewell', '500 block of N. 7th Ave', 0, 4, 0, 0, 1)
# Inserted data: ('2015-07-24', 'Pennsylvania', 'Erie', '200 block of W 29th St', 2, 3, 0, 2, 4)
# Inserted data: ('2015-07-23', 'Louisiana', 'Lafayette', '3141 Johnson Street', 2, 9, 1, 0, 0)
# Inserted data: ('2015-07-22', 'Missouri', 'Saint Louis', 'Fair Ave and Ashland Ave', 0, 6, 0, 0, 2)
# Inserted data: ('2015-07-22', 'Georgia', 'Suwanee', '5500 block of Old Atlanta Road', 4, 0, 1, 0, 0)
# Inserted data: ('2015-07-21', 'Florida', 'Miami Gardens', 'Northwest 25th Avenue and Miami Gardens Drive', 1, 3, 0, 0, 1)
# Inserted data: ('2015-07-20', 'New York', 'Bronx', 'E. 153rd St. and the Grand Concourse', 0, 6, 0, 0, 0)
# Inserted data: ('2015-07-19', 'Virginia', 'Suffolk', '100 block of North Capitol Street', 0, 4, 0, 0, 0)
# Scraping data for 2015, page 6
# Inserted data: ('2015-07-19', 'Kentucky', 'Louisville', '2928 W Kentucky St', 0, 6, 0, 0, 1)
# Inserted data: ('2015-07-19', 'North Carolina', 'Rocky Mount', 'US-64 and E Raleigh Blvd', 0, 4, 0, 0, 0)
# Inserted data: ('2015-07-18', 'California', 'San Diego', '200 block of South Bancroft Street', 0, 4, 0, 0, 0)
# Inserted data: ('2015-07-18', 'California', 'Santa Paula', 'Ojai-Santa Paula St', 0, 4, 0, 1, 1)
# Inserted data: ('2015-07-18', 'Oregon', 'Salem', '1550 Weston Ct NE', 1, 4, 0, 0, 0)
# Inserted data: ('2015-07-18', 'Louisiana', 'Baton Rouge', '300 block of Brice Street', 2, 2, 0, 0, 0)
# Inserted data: ('2015-07-17', 'Illinois', 'Chicago', '4400 block of W. Maypole', 0, 5, 0, 0, 0)
# Inserted data: ('2015-07-17', 'District of Columbia', 'Washington', '600 block of Edgewood St NE', 1, 3, 0, 0, 0)
# Inserted data: ('2015-07-17', 'Ohio', 'Cincinnati', '3100 block of Sunshine Ave', 0, 4, 0, 0, 0)
# Inserted data: ('2015-07-16', 'Texas', 'Dallas', '2261 Singleton Blvd', 0, 4, 0, 1, 1)
# Inserted data: ('2015-07-16', 'Tennessee', 'Chattanooga', '4051 Amnicola Hwy', 5, 2, 1, 0, 0)
# Inserted data: ('2015-07-15', 'Maryland', 'Baltimore', '3500 block of West Garrison Boulevard', 1, 3, 0, 0, 0)
# Inserted data: ('2015-07-15', 'Ohio', 'Cleveland', '700 block of Thornhill', 0, 7, 0, 0, 0)
# Inserted data: ('2015-07-15', 'South Carolina', 'Holly Hill', '7050 Old State Rd', 4, 1, 0, 0, 5)
# Inserted data: ('2015-07-15', 'Georgia', 'Atlanta', '500 block of Center Hill Ave NW', 0, 4, 0, 0, 0)
# Inserted data: ('2015-07-15', 'Michigan', 'Detroit', '9200 block of Memorial', 0, 4, 0, 0, 0)
# Inserted data: ('2015-07-14', 'Missouri', 'Saint Louis', '1100 block of Riverview', 0, 4, 0, 0, 0)
# Inserted data: ('2015-07-13', 'California', 'Norwalk', '11959 162nd Street', 0, 4, 0, 0, 0)
# Inserted data: ('2015-07-13', 'California', 'Stockton', '400 block of McCloud Avenue', 1, 4, 0, 0, 0)
# Inserted data: ('2015-07-12', 'Illinois', 'River Forest', '116 Lathrop Ave', 1, 3, 1, 0, 0)
# Inserted data: ('2015-07-12', 'New Jersey', 'Jersey City', 'Sip and Van Wagenen avenues', 0, 4, 0, 0, 0)
# Inserted data: ('2015-07-07', 'Ohio', 'Cleveland', 'East 162nd Street and Miles Avenue', 1, 3, 0, 0, 1)
# Inserted data: ('2015-07-07', 'Maryland', 'Baltimore', '900 block of West Fayette Street', 3, 1, 0, 0, 0)
# Inserted data: ('2015-07-05', 'Louisiana', 'Shreveport', '3500 block of Hearne Ave', 0, 5, 0, 1, 2)
# Inserted data: ('2015-07-05', 'Indiana', 'Fort Wayne', '1400 block of McCulloch Street', 0, 9, 0, 0, 0)
# Scraping data for 2015, page 7
# Inserted data: ('2015-07-05', 'New Jersey', 'East Orange', '200 block of S. Clinton St', 1, 3, 0, 0, 0)
# Inserted data: ('2015-07-04', 'Kentucky', 'Louisville', '2500 block of West Broadway', 0, 4, 0, 0, 0)
# Inserted data: ('2015-07-04', 'Massachusetts', 'Pittsfield', 'Dewey Avenue', 1, 4, 0, 0, 0)
# Inserted data: ('2015-07-04', 'District of Columbia', 'Washington', '2600 block of Douglass Pl SE', 1, 3, 0, 0, 4)
# Inserted data: ('2015-07-04', 'New York', 'Syracuse', 'Bellevue and Rich Street', 0, 4, 0, 0, 0)
# Inserted data: ('2015-07-04', 'Texas', 'San Antonio', '1100 block of West Avenue', 0, 4, 0, 0, 0)
# Inserted data: ('2015-07-02', 'Indiana', 'Indianapolis', '500 block of Lynn St', 1, 3, 0, 0, 1)
# Inserted data: ('2015-06-29', 'Florida', 'Opa Locka', '13450 NW 30th Ave', 0, 4, 0, 0, 0)
# Inserted data: ('2015-06-28', 'Illinois', 'Venice', '1430 Broadway', 0, 6, 0, 0, 2)
# Inserted data: ('2015-06-28', 'Michigan', 'Detroit', 'Gratiot and Loretto', 0, 5, 0, 0, 1)
# Inserted data: ('2015-06-28', 'Delaware', 'Harrington', '100 block of East St', 0, 6, 0, 0, 2)
# Inserted data: ('2015-06-27', 'Massachusetts', 'Taunton', 'Weir Street', 1, 3, 0, 0, 1)
# Inserted data: ('2015-06-27', 'Michigan', 'Detroit', 'Stringham Court', 0, 4, 0, 0, 0)
# Inserted data: ('2015-06-25', 'Louisiana', 'New Orleans', '2588 Martin Luther King Jr Blvd', 0, 4, 0, 0, 0)
# Inserted data: ('2015-06-24', 'New York', 'New York (Manhattan)', '2110 Madison Ave', 0, 4, 0, 0, 0)
# Inserted data: ('2015-06-22', 'Pennsylvania', 'Philadelphia', '700 block of East Hilton Street', 0, 7, 0, 0, 2)
# Inserted data: ('2015-06-21', 'Kentucky', 'Lexington', '726 Georgetown St', 1, 4, 0, 0, 0)
# Inserted data: ('2015-06-20', 'Pennsylvania', 'Philadelphia', '4100 block of Ogden St', 0, 10, 0, 0, 1)
# Inserted data: ('2015-06-20', 'North Carolina', 'Morven', '6066 Robinson Bridge Rd', 0, 4, 0, 0, 2)
# Inserted data: ('2015-06-20', 'Michigan', 'Detroit', 'Dexter and Webb', 1, 11, 0, 0, 0)
# Inserted data: ('2015-06-19', 'Rhode Island', 'Woonsocket', '80 River Street', 0, 4, 0, 0, 1)
# Inserted data: ('2015-06-17', 'South Carolina', 'Charleston', '110 Calhoun Street', 9, 1, 0, 0, 1)
# Inserted data: ('2015-06-16', 'Florida', 'Miami Gardens', '600 block of Northwest 177th Street', 0, 4, 0, 0, 1)
# Inserted data: ('2015-06-15', 'New York', 'Brooklyn', '673 Flatbush Avenue', 0, 4, 0, 0, 0)
# Inserted data: ('2015-06-14', 'New Jersey', 'Camden', '2800 block of Mitchell Street', 1, 3, 0, 0, 0)
# Scraping data for 2015, page 8
# Inserted data: ('2015-06-14', 'Oklahoma', 'Tulsa', '1800 block of North Kingston', 0, 4, 0, 0, 0)
# Inserted data: ('2015-06-14', 'Missouri', 'Saint Louis', '1400 block of North Market Street', 0, 4, 0, 0, 0)
# Inserted data: ('2015-06-13', 'Georgia', 'Fayetteville', '600 block of Highway 279', 1, 4, 0, 0, 1)
# Inserted data: ('2015-06-13', 'Oklahoma', 'Oklahoma City', '500 block of SE 69th St', 0, 4, 0, 0, 2)
# Inserted data: ('2015-06-13', 'Georgia', 'Milledgeville', '451 North Flynn Street', 1, 3, 0, 0, 0)
# Inserted data: ('2015-06-13', 'New York', 'Bronx', '2409 Creston Avenue', 0, 5, 0, 0, 0)
# Inserted data: ('2015-06-13', 'Ohio', 'Columbus', '1623 E. Hudson Street', 4, 1, 0, 0, 2)
# Inserted data: ('2015-06-12', 'Florida', 'Allapattah', '24th Avenue and 36th Street', 0, 4, 0, 0, 0)
# Inserted data: ('2015-06-11', 'Connecticut', 'Bridgeport', '468 Trumbull Ave', 1, 8, 0, 0, 2)
# Inserted data: ('2015-06-11', 'Texas', 'Houston', '3400 block of Burkett', 1, 3, 0, 0, 0)
# Inserted data: ('2015-06-10', 'California', 'Los Angeles', 'South Vermont Avenue and West 88th Street', 1, 3, 0, 0, 0)
# Inserted data: ('2015-06-09', 'Missouri', 'Saint Louis', 'North Market Street and North Spring Avenue', 1, 3, 0, 0, 0)
# Inserted data: ('2015-06-07', 'Montana', 'Deer Lodge', 'Boulder Creek Road', 4, 0, 1, 0, 0)
# Inserted data: ('2015-06-06', 'New York', 'Buffalo', '100 block of Warren Avenue', 1, 4, 0, 0, 1)
# Inserted data: ('2015-06-06', 'Illinois', 'Chicago', '100 block of North Lorel Avenue', 0, 5, 0, 0, 0)
# ...
# Inserted data: ('2023-04-15', 'Alabama', 'Dadeville', '220 N Broadnax St', 4, 32, 0, 0, 6)
# Inserted data: ('2023-04-15', 'Hawaii', 'Waianae', '87131 Kaukamana Rd', 2, 3, 0, 0, 2)
# Inserted data: ('2023-04-15', 'New Jersey', 'Paterson', '14th Ave and E 22nd St', 0, 6, 0, 0, 0)
# Inserted data: ('2023-04-15', 'New Jersey', 'Newark', '400 block of Leslie St', 1, 3, 0, 0, 1)
# Inserted data: ('2023-04-15', 'Arizona', 'Phoenix', '4617 W Indian School Rd', 0, 4, 0, 0, 0)
# Inserted data: ('2023-04-15', 'California', 'Northridge', '19105 Parthenia St', 2, 2, 0, 0, 1)
# Inserted data: ('2023-04-15', 'Kentucky', 'Louisville', '1200 Southwestern Pkwy', 2, 4, 0, 0, 0)
# Inserted data: ('2023-04-14', 'Missouri', 'Kansas City', '3500 Prospect Ave', 1, 4, 0, 0, 0)
# Inserted data: ('2023-04-13', 'New York', 'Bronx', '1859 Westchester Ave', 0, 4, 0, 0, 0)
# Inserted data: ('2023-04-13', 'Michigan', 'Detroit', '13570 block of Penrod St', 0, 4, 0, 1, 1)
# Scraping data for 2023, page 20
# Inserted data: ('2023-04-12', 'Ohio', 'Toledo', '998 Dorr St', 1, 5, 0, 0, 0)
# Inserted data: ('2023-04-12', 'Indiana', 'Fort Wayne', '3530 Harvester Ave', 1, 3, 0, 0, 0)
# Inserted data: ('2023-04-12', 'North Carolina', 'Goldsboro', '112 N. Leslie St', 1, 5, 0, 0, 0)
# Inserted data: ('2023-04-12', 'New Jersey', 'Trenton', 'Spring St and Calhoun St', 1, 3, 0, 0, 0)
# Inserted data: ('2023-04-11', 'District of Columbia', 'Washington', '4001 Benning Rd NE', 1, 3, 0, 0, 0)
# Inserted data: ('2023-04-10', 'Kentucky', 'Louisville', '333 E Main St', 5, 5, 1, 0, 0)
# Inserted data: ('2023-04-09', 'Florida', 'Orlando', '5344 Lescot Ln', 3, 2, 0, 0, 0)
# Inserted data: ('2023-04-08', 'Texas', 'Houston', '250 Uvalde Road', 0, 4, 0, 0, 0)
# Inserted data: ('2023-04-07', 'South Carolina', 'Isle Of Palms', '1140 Ocean Blvd', 0, 5, 0, 0, 1)
# Inserted data: ('2023-04-07', 'Louisiana', 'New Orleans', 'I-10 and Read Blvd', 0, 4, 0, 0, 0)
# Inserted data: ('2023-04-06', 'Pennsylvania', 'Philadelphia', '3700 block of N Carlisle St', 0, 4, 0, 0, 0)
# Inserted data: ('2023-04-05', 'Virginia', 'Virginia Beach', '700 block of Lake Edward Dr', 0, 4, 0, 0, 0)
# Inserted data: ('2023-04-04', 'Pennsylvania', 'Philadelphia', '3400 block of Rorer St', 1, 4, 0, 0, 0)
# Inserted data: ('2023-04-03', 'Tennessee', 'Jackson', '1600 block of Hollywood Dr', 0, 4, 0, 0, 0)
# Inserted data: ('2023-04-03', 'Georgia', 'Atlanta', '2479 Abner Terrace NW', 1, 3, 0, 0, 0)
# Inserted data: ('2023-04-03', 'Colorado', 'Pueblo', '1000 block of E 11th St', 1, 3, 0, 0, 0)
# Inserted data: ('2023-04-02', 'District of Columbia', 'Washington', '2900 block of Martin Luther King Jr Ave SE', 0, 4, 0, 0, 0)
# Inserted data: ('2023-04-02', 'North Carolina', 'Fayetteville', '5044 Yadkin Rd', 1, 3, 0, 1, 1)
# Inserted data: ('2023-04-02', 'California', 'Moreno Valley', '24700 block of Sunnymead Blvd', 0, 4, 0, 0, 0)
# Inserted data: ('2023-04-01', 'Maryland', 'Baltimore', '3205 Woodring Ave', 3, 1, 0, 0, 1)
# Inserted data: ('2023-03-29', 'Tennessee', 'Memphis', '6980 Winchester Rd', 2, 4, 0, 1, 3)
# Inserted data: ('2023-03-27', 'Tennessee', 'Nashville', '33 Burton Hills Blvd', 6, 0, 1, 0, 0)
# Inserted data: ('2023-03-27', 'Wisconsin', 'Milwaukee', '7225 N 76th St', 0, 5, 0, 0, 0)
# Inserted data: ('2023-03-26', 'Minnesota', 'Minneapolis', '5601 Brooklyn Blvd', 0, 6, 0, 0, 0)
# Inserted data: ('2023-03-26', 'Pennsylvania', 'Philadelphia', '1900 block of N 19th St', 2, 2, 0, 0, 0)
# Scraping data for 2023, page 21
# Inserted data: ('2023-03-26', 'Arkansas', 'Little Rock', '3002 Washington St', 2, 5, 0, 0, 0)
# Inserted data: ('2023-03-26', 'Louisiana', 'Minden', '801 Harris St', 0, 4, 0, 0, 3)
# Inserted data: ('2023-03-25', 'Illinois', 'Macomb', '533 N Johnson St', 1, 10, 0, 0, 2)
# Inserted data: ('2023-03-25', 'New York', 'Hempstead', 'Spencer Pl and Jerusalem Ave', 0, 4, 0, 0, 0)
# Inserted data: ('2023-03-25', 'Louisiana', 'Shreveport', '200 block of Texas St', 1, 5, 0, 0, 1)
# Inserted data: ('2023-03-25', 'North Carolina', 'Williamston', 'W Pine St', 0, 5, 0, 0, 0)
# Inserted data: ('2023-03-24', 'Louisiana', 'Shreveport', '1800 block of Logan St', 0, 8, 0, 0, 0)
# Inserted data: ('2023-03-23', 'Maryland', 'Baltimore', '2801 Edmondson Ave', 1, 5, 0, 0, 2)
# Inserted data: ('2023-03-21', 'New Jersey', 'Trenton', '45 N Stockton St', 0, 4, 0, 0, 0)
# Inserted data: ('2023-03-21', 'South Carolina', 'Sumter', '190 Whitetail Cir', 4, 0, 1, 0, 0)
# Inserted data: ('2023-03-20', 'Wisconsin', 'Milwaukee', 'N 14th St and W Concordia Ave', 1, 5, 0, 0, 1)
# Inserted data: ('2023-03-18', 'Ohio', 'Columbus', '1570 S. High St', 2, 4, 0, 0, 1)
# Inserted data: ('2023-03-18', 'Illinois', 'Chicago', '2425 E 72nd St', 0, 4, 0, 0, 0)
# Inserted data: ('2023-03-18', 'Texas', 'Dallas', 'Gannon Ln and S Westmoreland Rd', 0, 4, 0, 0, 0)
# Inserted data: ('2023-03-15', 'Oregon', 'Portland', '7900 NE 82nd Ave', 2, 2, 0, 0, 1)
# Inserted data: ('2023-03-14', 'Alabama', 'Birmingham', '8400 block of 8th Ave S', 4, 0, 0, 0, 1)
# Inserted data: ('2023-03-13', 'Texas', 'Lubbock', '9103 Ave P', 1, 3, 0, 0, 1)
# Inserted data: ('2023-03-12', 'Texas', 'Laredo', '4800 block of Roque Loop', 0, 14, 0, 0, 1)
# Inserted data: ('2023-03-12', 'Texas', 'Dallas', '3626 Villaverde Ave', 4, 0, 0, 0, 2)
# Inserted data: ('2023-03-11', 'New York', 'Brooklyn', 'E 45th St and Snyder Ave', 1, 3, 0, 0, 0)
# Inserted data: ('2023-03-11', 'Washington', 'Vancouver', '6701 E Mill Plain Blvd', 1, 3, 0, 0, 2)
# Inserted data: ('2023-03-10', 'Florida', 'Hialeah', '14811 NW 87th Ct', 4, 0, 1, 0, 0)
# Inserted data: ('2023-03-07', 'Tennessee', 'Memphis', '2100 block of Labelle St', 0, 4, 0, 0, 0)
# Inserted data: ('2023-03-07', 'Arkansas', 'Pine Bluff', '2611 W 34th St', 2, 2, 0, 0, 1)
# Inserted data: ('2023-03-06', 'California', 'Sacramento', '2200 block of Rogue River Dr', 3, 1, 0, 0, 1)
# Scraping data for 2023, page 22
# Inserted data: ('2023-03-06', 'Tennessee', 'Memphis', '176 Hillview Ave', 3, 1, 0, 0, 1)
# Inserted data: ('2023-03-05', 'Illinois', 'Bolingbrook', '123 Lee Lane', 3, 1, 0, 0, 1)
# Inserted data: ('2023-03-05', 'Maryland', 'Capitol Heights', '1200 block of Elfin Ave', 0, 4, 0, 0, 0)
# Inserted data: ('2023-03-05', 'Florida', 'Lake City', 'NW Alma Ave', 0, 4, 0, 0, 0)
# Inserted data: ('2023-03-05', 'Louisiana', 'Shreveport', '4725 Greenwood Rd', 0, 4, 0, 0, 0)
# Inserted data: ('2023-03-04', 'Missouri', 'Cape Girardeau', '15 N Main St', 0, 4, 0, 1, 3)
# Inserted data: ('2023-03-04', 'California', 'Los Angeles', 'E 76th Place and S Main St', 0, 4, 0, 0, 0)
# Inserted data: ('2023-03-04', 'Georgia', 'Douglasville', '3377 Talkeetna Rd', 2, 7, 0, 0, 6)
# Inserted data: ('2023-03-04', 'California', 'San Pedro', 'Paseo Del Mar and Graysby Ave', 0, 4, 0, 1, 1)
# Inserted data: ('2023-03-01', 'Florida', 'Cocoa', '4075 Alan Shepard Ave', 4, 0, 0, 0, 1)
# Inserted data: ('2023-02-27', 'Tennessee', 'Memphis', 'W Essex Ave and Arkansas St', 2, 2, 0, 1, 1)
# Inserted data: ('2023-02-27', 'Ohio', 'New Richmond', '1195 Riebel Ridge', 3, 1, 1, 0, 0)
# Inserted data: ('2023-02-26', 'Michigan', 'Detroit', '10300 block of Greensboro St', 2, 2, 0, 0, 0)
# Inserted data: ('2023-02-26', 'Florida', 'Pompano Beach', '401 NW 27th Ave', 2, 2, 0, 0, 1)
# Inserted data: ('2023-02-26', 'Tennessee', 'Memphis', '4675 S 3rd St', 1, 4, 0, 0, 0)
# Inserted data: ('2023-02-25', 'Minnesota', 'Saint Paul', '500 Dale St N', 2, 3, 0, 0, 1)
# Inserted data: ('2023-02-25', 'Illinois', 'Machesney Park', '1001 West Lane Rd', 0, 4, 0, 0, 2)
# Inserted data: ('2023-02-24', 'Louisiana', 'Abbeville', '1616 Veterans Memorial Dr', 0, 4, 0, 0, 2)
# Inserted data: ('2023-02-23', 'Pennsylvania', 'Philadelphia', '2003-05 N 31st St', 0, 7, 0, 0, 0)
# Inserted data: ('2023-02-22', 'Alabama', 'Daphne', '123 block of Melanie Loop', 4, 0, 0, 0, 1)
# Inserted data: ('2023-02-22', 'Florida', 'Orlando', '6100 block of Hialeah St', 3, 2, 0, 0, 1)
# Inserted data: ('2023-02-21', 'Colorado', 'Colorado Springs', '3945 Palmer Park Blvd', 0, 5, 0, 0, 0)
# Inserted data: ('2023-02-19', 'Illinois', 'Chicago', 'I-57 and W 111th St', 3, 3, 0, 0, 0)
# Inserted data: ('2023-02-19', 'Indiana', 'Indianapolis', '8005 42nd St', 0, 4, 0, 0, 0)
# Inserted data: ('2023-02-19', 'Tennessee', 'Memphis', '1482 E Shelby Dr', 1, 10, 0, 0, 2)
# Scraping data for 2023, page 23
# Inserted data: ('2023-02-19', 'Louisiana', 'New Orleans', 'St Charles Ave and Terpsichore St', 1, 4, 0, 0, 1)
# Inserted data: ('2023-02-18', 'Missouri', 'Saint Louis', '410 N Tucker Blvd', 0, 4, 0, 0, 0)
# Inserted data: ('2023-02-18', 'Georgia', 'Columbus', '3048 Victory Dr', 3, 1, 0, 0, 1)
# Inserted data: ('2023-02-18', 'South Carolina', 'Loris', '3450 East SC 9 Business', 0, 4, 0, 0, 0)
# Inserted data: ('2023-02-17', 'Mississippi', 'Coldwater', '3196 Arkabutla Dam Road', 6, 0, 0, 0, 1)
# Inserted data: ('2023-02-17', 'Georgia', 'Columbus', '4499 Warm Springs Rd Connector', 0, 9, 0, 0, 2)
# Inserted data: ('2023-02-15', 'Maryland', 'Baltimore', '1400 block of E Fayette St', 0, 4, 0, 0, 0)
# Inserted data: ('2023-02-15', 'Texas', 'El Paso', '8401 Gateway Blvd W', 1, 3, 0, 1, 1)
# Inserted data: ('2023-02-14', 'Pennsylvania', 'Pittsburgh', '1101 N Murtland St', 0, 4, 0, 0, 2)
# Inserted data: ('2023-02-14', 'New York', 'Buffalo', 'Crossman Ave and Heminway St', 0, 5, 0, 0, 0)
# Inserted data: ('2023-02-13', 'New Jersey', 'Paterson', '50 block of 12th Ave', 0, 4, 0, 0, 0)
# Inserted data: ('2023-02-13', 'Michigan', 'East Lansing', '509 E Circle Dr', 3, 5, 1, 0, 0)
# Inserted data: ('2023-02-12', 'Mississippi', 'Louisville', '309 E John C Stennis Dr', 1, 5, 0, 0, 0)
# Inserted data: ('2023-02-10', 'New York', 'Brooklyn', '3222 Mermaid Ave', 0, 4, 0, 0, 0)
# Inserted data: ('2023-02-10', 'New York', 'Bronx', '631 E Tremont Ave', 2, 2, 0, 0, 2)
# Inserted data: ('2023-02-08', 'North Carolina', 'Laurinburg', 'Marcellus St', 0, 4, 0, 0, 0)
# Inserted data: ('2023-02-08', 'Louisiana', 'New Orleans', 'Bullard Ave and Chef Menteur Hwy', 2, 4, 0, 0, 0)
# Inserted data: ('2023-02-08', 'North Carolina', 'Elizabeth City', '1000 block of Walker Ave', 0, 4, 0, 0, 0)
# Inserted data: ('2023-02-06', 'Texas', 'Corpus Christi', '2700 block of Persimmon St', 1, 3, 0, 1, 3)
# Inserted data: ('2023-02-05', 'Arizona', 'Tucson', '4000 block of E Agate Knoll Dr', 1, 3, 0, 0, 1)
# Inserted data: ('2023-02-05', 'Arkansas', 'Newport', '400 block of Clay St', 1, 4, 0, 0, 4)
# Inserted data: ('2023-02-05', 'California', 'Stockton', '1300 block of W Fremont St', 1, 3, 0, 0, 0)
# Inserted data: ('2023-02-05', 'Colorado', 'Peyton', '12252 Point Reyes Dr', 2, 3, 0, 0, 0)
# Inserted data: ('2023-02-04', 'Texas', 'Huntsville', '1505 19th St', 2, 2, 0, 0, 2)
# Inserted data: ('2023-02-01', 'California', 'Los Angeles', '711 E. 108 St', 0, 5, 0, 0, 0)
# Scraping data for 2023, page 24
# Inserted data: ('2023-02-01', 'Texas', 'Texas City', '8601 Emmett F Lowry Expy', 0, 4, 0, 0, 0)
# Inserted data: ('2023-01-31', 'North Carolina', 'Durham', '4100 block of Sudbury Rd', 2, 2, 0, 0, 2)
# Inserted data: ('2023-01-30', 'Florida', 'Lakeland', '923 N Iowa Ave', 0, 11, 0, 0, 5)
# Inserted data: ('2023-01-30', 'Texas', 'Dallas', '5800 block of Bonnie View Rd', 1, 3, 0, 1, 1)
# Inserted data: ('2023-01-29', 'Tennessee', 'Luttrell', '380 Clinch Valley Rd', 4, 0, 1, 0, 0)
# Inserted data: ('2023-01-29', 'Ohio', 'Columbus', '1680 Karl Ct', 1, 3, 0, 0, 1)
# Inserted data: ('2023-01-29', 'North Carolina', 'Greensboro', '6400 W Market St', 1, 6, 0, 0, 1)
# Inserted data: ('2023-01-28', 'South Carolina', 'Andrews', 'Birch Creek Rd', 2, 2, 0, 0, 1)
# Inserted data: ('2023-01-28', 'Texas', 'Austin', '12636 Research Blvd', 2, 3, 0, 0, 1)
# Inserted data: ('2023-01-28', 'California', 'Beverly Hills', '2799 Ellison Dr', 3, 2, 0, 0, 3)
# Inserted data: ('2023-01-28', 'Pennsylvania', 'Philadelphia', 'Knorr St and Loretto Ave', 0, 4, 0, 0, 0)
# Inserted data: ('2023-01-27', 'California', 'San Diego', '62nd St and Akins Ave', 1, 4, 0, 0, 1)
# Inserted data: ('2023-01-26', 'New Jersey', 'Newark', '1079 Broad St', 1, 4, 0, 0, 0)
# Inserted data: ('2023-01-26', 'Pennsylvania', 'Lancaster', '525 N Franklin St', 0, 4, 0, 0, 0)
# Inserted data: ('2023-01-24', 'North Carolina', 'Red Springs', '100 block of Samuel Williams Dr', 3, 1, 0, 0, 1)
# Inserted data: ('2023-01-23', 'Illinois', 'Chicago', '2909 E 78th St', 2, 3, 0, 0, 0)
# Inserted data: ('2023-01-23', 'California', 'Oakland', '5910 MacArthur Blvd', 1, 4, 0, 0, 2)
# Inserted data: ('2023-01-23', 'California', 'Half Moon Bay', '12761 San Mateo Rd', 7, 1, 0, 0, 1)
# Inserted data: ('2023-01-22', 'Louisiana', 'Shreveport', '1600 Sugar Ln', 1, 7, 0, 0, 0)
# Inserted data: ('2023-01-22', 'Louisiana', 'Baton Rouge', '4619 Bennington Ave', 0, 12, 0, 0, 3)
# Inserted data: ('2023-01-22', 'Mississippi', 'Robinsonville (Tunica Resorts)', '1010 Casino Center Dr', 0, 4, 0, 0, 1)
# Inserted data: ('2023-01-21', 'California', 'Monterey Park', '122 W Garvey Ave', 11, 9, 1, 0, 0)
# Inserted data: ('2023-01-21', 'Arizona', 'Yuma', '1300 block of W 9th St', 0, 5, 0, 0, 1)
# Inserted data: ('2023-01-17', 'Texas', 'Houston', '6729 Lockwood Dr', 0, 4, 0, 0, 0)
# Inserted data: ('2023-01-16', 'California', 'Goshen', 'Harvest Ave and Rd 68', 6, 0, 0, 0, 2)
# Scraping data for 2023, page 25
# Inserted data: ('2023-01-16', 'Florida', 'Sanford', 'Rinehart Rd and Co Rd 46A', 1, 5, 0, 0, 11)
# Inserted data: ('2023-01-16', 'Florida', 'Fort Pierce', 'Avenue M and N 13th St', 1, 7, 0, 0, 1)
# Inserted data: ('2023-01-15', 'Illinois', 'Rockford', '2311 23rd St', 3, 1, 0, 1, 0)
# Inserted data: ('2023-01-15', 'Texas', 'Houston', '5121 FM 1960 Rd W', 1, 4, 0, 0, 0)
# Inserted data: ('2023-01-15', 'Florida', 'Homestead', '700 block of SW Sixth St', 1, 3, 0, 0, 0)
# Inserted data: ('2023-01-15', 'Arizona', 'Phoenix', 'S 46th Pl and E Broadway Rd', 0, 4, 0, 0, 0)
# Inserted data: ('2023-01-14', 'Missouri', 'Saint Louis (Moline Acres)', 'Berwyn Dr and Lanier Dr', 0, 4, 0, 0, 0)
# Inserted data: ('2023-01-13', 'Ohio', 'Cleveland', '3719 Mack Ct', 4, 1, 0, 0, 1)
# Inserted data: ('2023-01-09', 'Minnesota', 'Minneapolis', '2218 E Lake St', 0, 4, 0, 0, 0)
# Inserted data: ('2023-01-09', 'Pennsylvania', 'Philadelphia', '3300 block of Guilford St', 3, 1, 0, 0, 1)
# Inserted data: ('2023-01-09', 'Colorado', 'Denver', '18th St and Blake St', 0, 4, 0, 0, 0)
# Inserted data: ('2023-01-08', 'Minnesota', 'Minneapolis', '930 Hennepin Ave', 0, 4, 0, 0, 0)
# Inserted data: ('2023-01-08', 'Georgia', 'Albany', '1021 S McKinley St', 0, 4, 0, 0, 0)
# Inserted data: ('2023-01-07', 'North Carolina', 'High Point', '2734 Mossy Meadow Dr', 4, 0, 1, 0, 0)
# Inserted data: ('2023-01-07', 'Alabama', 'Huntsville', '2817 Hwy 72 E', 2, 9, 0, 0, 3)
# Inserted data: ('2023-01-06', 'Texas', 'Dallas', '8544 Lazy Acres Cir', 3, 2, 0, 0, 1)
# Inserted data: ('2023-01-06', 'California', 'San Francisco', '600 block of Valencia St', 1, 3, 0, 0, 0)
# Inserted data: ('2023-01-05', 'Louisiana', 'New Orleans', 'St Andrew St and Rev John Raphael Jr Way', 2, 3, 0, 0, 0)
# Inserted data: ('2023-01-05', 'Florida', 'Miami Gardens', '17647 NW 27th Ave', 0, 10, 0, 0, 0)
# Inserted data: ('2023-01-04', 'Maryland', 'Baltimore', '4408 Edmondson Ave', 1, 4, 0, 0, 1)
# Inserted data: ('2023-01-04', 'Utah', 'Cedar City (Enoch)', '4923 N Albert Dr', 7, 0, 1, 0, 0)
# Inserted data: ('2023-01-04', 'Virginia', 'Dumfries', '17900 block of Milroy Dr', 1, 4, 0, 0, 1)
# Inserted data: ('2023-01-03', 'Louisiana', 'New Orleans', '2600 block of S Rocheblave St', 0, 4, 0, 0, 0)
# Inserted data: ('2023-01-03', 'District of Columbia', 'Washington', '6200 block of Georgia Ave NW', 1, 3, 0, 0, 0)
# Inserted data: ('2023-01-01', 'Florida', 'Miami Gardens', 'NW 171st St and NW 30th Ave', 0, 9, 0, 0, 0)
# Scraping data for 2023, page 26
# Inserted data: ('2023-01-01', 'Illinois', 'Chicago', '300 block of E 57th St', 1, 3, 0, 0, 0)
# Inserted data: ('2023-01-01', 'North Carolina', 'Durham', '1000 N Miami Blvd', 0, 5, 0, 0, 0)
# Inserted data: ('2023-01-01', 'Pennsylvania', 'Allentown', '1140 E Clair St', 0, 4, 0, 0, 0)
# Inserted data: ('2023-01-01', 'Florida', 'Ocala', '1600 block of SW 5th St', 2, 4, 0, 0, 1)
# Inserted data: ('2023-01-01', 'Ohio', 'Columbus', '2830 Johnstown Rd', 1, 4, 0, 0, 2)
# Data scraping and insertion completed.
